# %%
import pandas as pd
## load the dataset
df = pd.read_csv('chicago_taxi.csv')
df
# Out:
#                                          Trip ID  \
# 0       fec6b8b1c5cd7af9e6dc4e9c8c46fb08987f2e9c
# 1       ff5cad1f181d44fe60b9d0a1330f78269511d54a
# 2       fbe685844176dd7822b6e256efce7fa3f8909e4b
# 3       fddd99b2c6db17848390d4b57e7fff970e22b413
# 4       f9f914b68a3ddb07fba1acf5bfcb5e1c7bb5f3bc
# ...                                          ...
# 292777  5bbfd687aafb778e609425ba4621d9e291ef44c0
# 292778  5b49d22a619c543597c7e09731772f2453f6fbf3
# 292779  587c59ccd2e9c2e0223817faaa58427184a642c0
# 292780  585d981c08bb404e5ec19b470a67f573a16152da
# 292781  57a8e88f4a80a766c45228ba2b19afe00171b1fd
#
#                                                   Taxi ID  \
# 0       56a1119c6ca57e39525cf06829f9ecff553cf4b5ac2482...
# 1       6acd828b5cde8b4529317e8eda5b4fb9663fa81d1143c9...
# 2       b968bad5a2daed924a10e8ec4fb35513e060a076c575f7...
# 3       a4e718943931c99476ac0b332bb99261dd8e15994076bf...
# 4       cbdd490649df25aa771979bed8930b199d27a990ccdb42...
# ...

# %%
import pandas as pd
## load the dataset
df2 = pd.read_csv('MopsiLocationsUntil2012-Finland.txt', delimiter='\t')
df2
# Out:
#        625983\t297439
# 0      626146\t297440
# 1      626144\t297456
# 2      626004\t297394
# 3      626018\t297437
# 4      626038\t297518
# ...               ...
# 13461  626042\t297444
# 13462  625977\t297443
# 13463  626050\t297404
# 13464  625995\t297426
# 13465  625982\t297431
#
# [13466 rows x 1 columns]
